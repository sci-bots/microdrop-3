# %%
import microdrop_async

# %%
print('hi there')
# Out:
# hi there

# %%
x = microdrop_async.MicrodropAsync()
y = x.client_ready()
print('awaiting response')
y.then(lambda d: print('connected'), lambda d: print('failed to connect'))
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# <ipython-input-3-bc7483362a81> in <module>()
# ----> 1 x = microdrop_async.MicrodropAsync()
#       2 y = x.client_ready()
#       3 print('awaiting response')
#       4 y.then(lambda d: print('connected'), lambda d: print('failed to connect'))
#
# ~/Developer/microdropRepos/microdrop-3.0/packages/async-python/microdrop_async/__init__.py in __init__(self)
#      14     def __init__(self):
#      15         self._name = generateId()
# ---> 16         super().__init__()
#      17
#      18     @property
#
# ~/miniconda3/lib/python3.6/site-packages/mqttclient/__init__.py in __init__(self, host, port, base)
#      39         self.subscriptions = []
#      40         self.client_id = self.ClientID()
# ---> 41         self.client = self.Client()
#      42         self.connected = False
#      43
#
# ~/miniconda3/lib/python3.6/site-packages/mqttclient/__init__.py in Client(self, keepalive)
#     100         client.on_message = self.on_message
#     101         client.on_disconnect = self.on_disconnect
# --> 102         client.connect(host=self.host, port=self.port)
#     103         client.loop_start()
#     104         return client
#
# ~/miniconda3/lib/python3.6/site-packages/paho/mqtt/client.py in connect(self, host, port, keepalive, bind_address)
#     766         """
#     767         self.connect_async(host, port, keepalive, bind_address)
# --> 768         return self.reconnect()
#     769
#     770     def connect_srv(self, domain=None, keepalive=60, bind_address=""):
#
# ~/miniconda3/lib/python3.6/site-packages/paho/mqtt/client.py in reconnect(self)
#     893                 sock = socket.create_connection((self._host, self._port))
#     894             else:
# --> 895                 sock = socket.create_connection((self._host, self._port), source_address=(self._bind_address, 0))
#     896         except socket.error as err:
#     897             if err.errno != errno.EINPROGRESS and err.errno != errno.EWOULDBLOCK and err.errno != EAGAIN:
#
# ~/miniconda3/lib/python3.6/socket.py in create_connection(address, timeout, source_address)
#     722
#     723     if err is not None:
# --> 724         raise err
#     725     else:
#     726         raise error("getaddrinfo returns an empty list")
#
# ~/miniconda3/lib/python3.6/socket.py in create_connection(address, timeout, source_address)
#     711             if source_address:
#     712                 sock.bind(source_address)
# --> 713             sock.connect(sa)
#     714             # Break explicitly a reference cycle
#     715             err = None
#
# ConnectionRefusedError: [Errno 61] Connection refused

# %%
x.name
# Out:
# 'microdrop-async-1512588804547127-900'
# rejecting...
